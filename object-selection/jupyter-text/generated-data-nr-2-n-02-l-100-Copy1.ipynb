# %%
import os
import sys
parent_dir = os.path.split(os.getcwd())[0]
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import random
import pickle

from utils import divide_texts, save_scores
from object_selection import ObjectSelection
from load_data import load_data
import matplotlib.pyplot as plt
from basic_factorization import BasicFactorization

# Parameters
data_directory = '../../data/generated-data-nr-2-n-02-l-100/'
booking_file = '../../data/booking.csv'
users_file = '../../data/user.csv'
rating_thresholds = []
true_objects_indexes = [0, 1, 2, 3, 4, 5, 6, 7]
false_objects_indexes = [8, 9]

file_names = os.listdir(data_directory)
ids_vector = [int(name.split('-')[0]) for name in file_names]
categories_vector = [name.split('-')[1] for name in file_names]
ratings_vector = [int(name.split('.')[0].split('-')[2]) for name in file_names]
name_vector = [data_directory + name for name in file_names]

ratings_matrix, images_indexes_for_id, ids_indexes, users_matrix = load_data(data_directory, booking_file,
                                                                             users_file, rating_thresholds, binary=True)

features, new_ratings_vector, new_categories_vector, new_ids_vector, new_paths_vector, text_indexes = divide_texts(name_vector, ratings_vector, categories_vector, ids_vector, n=10)

ratings_vector = new_ratings_vector
ids_vector = new_ids_vector

cv_results_file = '../results/cv-generated-data-nr-2-n-02-l-100-knn.csv'
scores = []
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='knn')
    selection.transform(ids=ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=text_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    score = selection.evaluate(evaluation_metric='auc')
    scores.append(score)
    
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

scores.sort()
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

results_file = '../scores/generated-data-nr-2-n-02-l-100-knn.csv'
save_scores(scores, results_file)
# Out:
# /Users/tinaavbelj/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/tinaavbelj/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6481999171446566
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6479450077580919
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6557201889991933
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6379899264748452
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6463065010370725
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6626675154114179
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6655737970995674
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6562327732127917
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6741582785176596
#
# Preselection
#
# (3819, 100)
# -
# 3253
# 0.8517936632626343
# -
# -
# 3170
# 0.9744843300967571
# -
# -
# 3151
# 0.9940073034029987
# -
# -
# 3147
# 0.9987307628411339
# -
# -
# 3145
# 0.9993644741023197
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977742448330683
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.664549848912683

# %%
cv_results_file = '../results/cv-generated-data-nr-2-n-02-l-100-rf.csv'
scores = []
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='rf')
    selection.transform(ids=ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=text_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    score = selection.evaluate(evaluation_metric='auc')
    scores.append(score)
    
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

scores.sort()
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

results_file = '../scores/generated-data-nr-2-n-02-l-100-rf.csv'
save_scores(scores, results_file)
# Out:
# Preselection
#
# (3819, 100)
# -
# 3304
# 0.8651479444880859
# -
# -
# 3231
# 0.9779062975802123
# -
# -
# 3213
# 0.9944289693593316
# -
# -
# 3199
# 0.9956427015250545
# -
# -
# 3190
# 0.9971866202693459
# -
# -
# 3187
# 0.9990595609437517
# -
# -
# 3182
# 0.9984312245660844
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9987429289754871
# Dfmf
#
# Parameters
#
# 18 18 8 2
#
#
# auc: 0.6955690500817457
#
# Preselection
#
# (3819, 100)
# -
# 3305
# 0.8654097931395652
# -
# -
# 3231
# 0.9776104108183014
# -
# -
# 3204
# 0.9916434540389972
# -
# -
# 3194
# 0.9968789013732834
# -
# -
# 3188
# 0.9981211832397895
# -
# -
# 3183
# 0.9984318151083142
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9971724787935909
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.6522717341334369
#
# Preselection
#
# (3819, 100)
# -
# 3308
# 0.8661953390940037
# -
# -
# 3236
# 0.9782351273187189
# -
# -
# 3208
# 0.9913474362699836
# -
# -
# 3193
# 0.995324480036369
# -
# -
# 3183
# 0.9968674620824362
# -
# -
# 3179
# 0.9987433239082626
# -
# -
# 3175
# 0.9987415444735451
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9990551181102362
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.6611953881508738
#
# Preselection
#
# (3819, 100)
# -
# 3299
# 0.8638387012306886
# -
# -
# 3235
# 0.9805991672870654
# -
# -
# 3213
# 0.993199284937667
# -
# -
# 3198
# 0.9953314659197012
# -
# -
# 3195
# 0.99906191369606
# -
# -
# 3188
# 0.9978090766823161
# -
# -
# 3185
# 0.9990586756854277
# -
# -
# 3182
# 0.9990583804143126
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9987429289754871
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.65890160809489
#
# Preselection
#
# (3819, 100)
# -
# 3309
# 0.8664571877454832
# -
# -
# 3235
# 0.9776367482623148
# -
# -
# 3207
# 0.9913439973680939
# -
# -
# 3197
# 0.9968818210165263
# -
# -
# 3190
# 0.9978102511252631
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9981191222570532
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.6393689276533537
#
# Preselection
#
# (3819, 100)
# -
# 3324
# 0.8703849175176748
# -
# -
# 3252
# 0.9783393501805054
# -
# -
# 3230
# 0.9932349323493236
# -
# -
# 3215
# 0.9953566115431478
# -
# -
# 3208
# 0.9978225120894129
# -
# -
# 3201
# 0.9978178575487616
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9984379881287098
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.6373038493038493
#
# Preselection
#
# (3819, 100)
# -
# 3314
# 0.8677664310028802
# -
# -
# 3251
# 0.9809900102738977
# -
# -
# 3222
# 0.9910792875241771
# -
# -
# 3209
# 0.9959652389819987
# -
# -
# 3195
# 0.9956377550276994
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9968701095461658
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.6524927188065851
#
# Preselection
#
# (3819, 100)
# -
# 3310
# 0.8667190363969626
# -
# -
# 3238
# 0.9782469089571263
# -
# -
# 3212
# 0.9919695877527203
# -
# -
# 3196
# 0.9950184850679628
# -
# -
# 3188
# 0.9974978493013532
# -
# -
# 3184
# 0.9987450977613136
# -
# -
# 3177
# 0.9978011126671649
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9990557129367328
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.6491266354051473
#
# Preselection
#
# (3819, 100)
# -
# 3305
# 0.8654097931395653
# -
# -
# 3236
# 0.9791217135827134
# -
# -
# 3206
# 0.9907287205049684
# -
# -
# 3196
# 0.9968809451235535
# -
# -
# 3187
# 0.9971836858130229
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9974898023219329
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.6601450714450822
#
# Preselection
#
# (3819, 100)
# -
# 3325
# 0.8706467661691543
# -
# -
# 3251
# 0.977744989848944
# -
# -
# 3222
# 0.9910801393332492
# -
# -
# 3207
# 0.9953445065176908
# -
# -
# 3198
# 0.9971936389148737
# -
# -
# 3195
# 0.99906191369606
# -
# -
# 3190
# 0.998435054773083
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9993730407523511
# Dfmf
#
# Parameters
#
# 10 10 2 8
#
#
# auc: 0.650605482432777

# %%
cv_results_file = '../results/cv-generated-data-nr-2-n-02-l-100-random.csv'
scores = []
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='random')
    selection.transform(ids=ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=text_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    score = selection.evaluate(evaluation_metric='auc')
    scores.append(score)
    
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

scores.sort()
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

results_file = '../scores/generated-data-nr-2-n-02-l-100-random.csv'
save_scores(scores, results_file)
# Out:
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 18 18 6 2
#
#
# auc: 0.7205176186374391
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6549258301667515
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6597026828723642
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6441957796201339
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6475612125923047
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6449269784750482
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6536181018308858
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6556226657329598
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6640184005946044
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 14 4 4
#
#
# auc: 0.6469234174413457

# %%
cv_results_file = '../results/cv-generated-data-nr-2-n-02-l-100-knn.csv'
scores = []
for _ in range(10):
    selection = BasicFactorization(show_selection_results=True, selection_algorithm='random')
    selection.transform(ids=ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=text_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    score = selection.evaluate(evaluation_metric='auc')
    scores.append(score)
    
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

scores.sort()
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

results_file = '../scores/generated-data-nr-2-n-02-l-100-b.csv'
save_scores(scores, results_file)
# Out:
# Object selection: random
#
# Dfmf
#
# auc: 0.6806674806674807
# Object selection: random
#
# Dfmf
#
# auc: 0.6723018794807208
# Object selection: random
#
# Dfmf
#
# auc: 0.6638118782741774
# Object selection: random
#
# Dfmf
#
# auc: 0.6592743106887625
# Object selection: random
#
# Dfmf
#
# auc: 0.6794863891502547
# Object selection: random
#
# Dfmf
#
# auc: 0.6540988879698557
# Object selection: random
#
# Dfmf
#
# auc: 0.6824062685071295
# Object selection: random
#
# Dfmf
#
# auc: 0.6586277975038528
# Object selection: random
#
# Dfmf
#
# auc: 0.6585404571843251
# Object selection: random
#
# Dfmf
#
# auc: 0.6527731239346747
