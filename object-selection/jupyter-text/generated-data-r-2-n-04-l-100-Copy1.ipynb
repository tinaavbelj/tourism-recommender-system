# %%
import os
import sys
parent_dir = os.path.split(os.getcwd())[0]
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import random
import pickle

from utils import divide_texts, save_scores
from object_selection import ObjectSelection
from load_data import load_data
import matplotlib.pyplot as plt
from basic_factorization import BasicFactorization

# Parameters
data_directory = '../../data/generated-data-r-2-n-04-l-100/'
booking_file = '../../data/booking.csv'
users_file = '../../data/user.csv'
rating_thresholds = [1, 7]
true_objects_indexes = [0, 1, 2, 3, 4, 5]
false_objects_indexes = [6, 7, 8, 9]

file_names = os.listdir(data_directory)
ids_vector = [int(name.split('-')[0]) for name in file_names]
categories_vector = [name.split('-')[1] for name in file_names]
ratings_vector = [int(name.split('.')[0].split('-')[2]) for name in file_names]
name_vector = [data_directory + name for name in file_names]

ratings_matrix, images_indexes_for_id, ids_indexes, users_matrix = load_data(data_directory, booking_file,
                                                                             users_file, rating_thresholds, binary=True)

features, new_ratings_vector, new_categories_vector, new_ids_vector, new_paths_vector, text_indexes = divide_texts(name_vector, ratings_vector, categories_vector, ids_vector, n=10)

ratings_vector = new_ratings_vector
ids_vector = new_ids_vector

cv_results_file = '../results/cv-generated-data-r-2-n-04-l-100-knn.csv'
scores = []
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='knn')
    selection.transform(ids=ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=text_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    score = selection.evaluate(evaluation_metric='auc')
    scores.append(score)
    
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

scores.sort()
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

results_file = '../scores/generated-data-r-2-n-04-l-100-knn.csv'
save_scores(scores, results_file)
# Out:
# /Users/tinaavbelj/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/tinaavbelj/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 18 18 4 2
#
#
# auc: 0.7204182661589849
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.7039873124778785
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.7034021827396353
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.689451065972805
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.6895230795435191
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.7009373840914456
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.6930960086299892
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.6918169491525423
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.7026063730243794
#
# Preselection
#
# (3844, 100)
# -
# 2813
# 0.7317918633997507
# -
# -
# 2662
# 0.946321904731564
# -
# -
# 2632
# 0.9887306980035278
# -
# -
# 2628
# 0.9984800984234755
# -
# -
# 2627
# 0.9996194824961947
# -
# -
# 2626
# 0.9996190476190477
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.9897182025894897
# Dfmf
#
# Parameters
#
# 16 10 6 8
#
#
# auc: 0.6966182791338902

# %%
cv_results_file = '../results/cv-generated-data-r-2-n-04-l-100-rf.csv'
scores = []
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='rf')
    selection.transform(ids=ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=text_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    score = selection.evaluate(evaluation_metric='auc')
    scores.append(score)
    
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

scores.sort()
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

results_file = '../scores/generated-data-r-2-n-04-l-100-rf.csv'
save_scores(scores, results_file)
# Out:
# Preselection
#
# (3844, 100)
# -
# 2853
# 0.7422014132712068
# -
# -
# 2721
# 0.953732912723449
# -
# -
# 2679
# 0.9845644983461962
# -
# -
# 2653
# 0.990294886151549
# -
# -
# 2632
# 0.992082726180433
# -
# -
# 2622
# 0.9962013283013379
# -
# -
# 2614
# 0.9969488939740656
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9984697781178271
# Dfmf
#
# Parameters
#
# 16 18 8 2
#
#
# auc: 0.7364917663697936
#
# Preselection
#
# (3844, 100)
# -
# 2877
# 0.7484447074994631
# -
# -
# 2748
# 0.9551616266944732
# -
# -
# 2699
# 0.9821688500727802
# -
# -
# 2673
# 0.9903658385860833
# -
# -
# 2654
# 0.9928918817807707
# -
# -
# 2643
# 0.9958555956063434
# -
# -
# 2631
# 0.9954597048808171
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9973394146712277
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.7103736630560665
#
# Preselection
#
# (3844, 100)
# -
# 2875
# 0.7479254985968368
# -
# -
# 2725
# 0.9478286140965384
# -
# -
# 2680
# 0.9834874456608658
# -
# -
# 2657
# 0.9914184647682321
# -
# -
# 2644
# 0.9951074041482274
# -
# -
# 2631
# 0.9950834918404238
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9958190801976435
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.7208542095848488
#
# Preselection
#
# (3844, 100)
# -
# 2891
# 0.7520868828508019
# -
# -
# 2749
# 0.9508864644688897
# -
# -
# 2704
# 0.9836300098892186
# -
# -
# 2683
# 0.9922337256870701
# -
# -
# 2669
# 0.9947825145080591
# -
# -
# 2654
# 0.9943794946979944
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9947249434815373
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.699411538525837
#
# Preselection
#
# (3844, 100)
# -
# 2866
# 0.7455841871457839
# -
# -
# 2716
# 0.947664059818762
# -
# -
# 2678
# 0.9860085617064872
# -
# -
# 2656
# 0.9917863067170837
# -
# -
# 2639
# 0.9935995374798604
# -
# -
# 2626
# 0.9950744647843625
# -
# -
# 2615
# 0.9958108284409654
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9977055449330784
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.7023904007317827
#
# Preselection
#
# (3844, 100)
# -
# 2876
# 0.7481861179209073
# -
# -
# 2738
# 0.9520163154178668
# -
# -
# 2692
# 0.9832003452406116
# -
# -
# 2667
# 0.9907118424112711
# -
# -
# 2652
# 0.9943757030371203
# -
# -
# 2644
# 0.9969834087481146
# -
# -
# 2632
# 0.9954618497670223
# -
# -
# 2625
# 0.9973398475682874
# -
# -
# 2616
# 0.9965714285714286
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9984709480122325
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.6951093974867715
#
# Preselection
#
# (3844, 100)
# -
# 2881
# 0.7494869818211932
# -
# -
# 2740
# 0.9510626228465718
# -
# -
# 2694
# 0.9832119406609929
# -
# -
# 2675
# 0.9929472902746844
# -
# -
# 2651
# 0.991028034874572
# -
# -
# 2636
# 0.9943426102909149
# -
# -
# 2631
# 0.9981026102174851
# -
# -
# 2622
# 0.9965792474344356
# -
# -
# 2615
# 0.9973302822273075
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9961759082217974
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.6851674641148325
#
# Preselection
#
# (3844, 100)
# -
# 2861
# 0.7442827143218437
# -
# -
# 2725
# 0.9524639173216655
# -
# -
# 2674
# 0.9812864179222621
# -
# -
# 2652
# 0.99177290258506
# -
# -
# 2632
# 0.9924585218702866
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9954407294832827
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.7079028765852149
#
# Preselection
#
# (3844, 100)
# -
# 2892
# 0.7523472992003208
# -
# -
# 2747
# 0.9498616874135545
# -
# -
# 2697
# 0.9818001765814781
# -
# -
# 2671
# 0.9903596588802372
# -
# -
# 2653
# 0.9932613694161759
# -
# -
# 2640
# 0.9950997435045291
# -
# -
# 2629
# 0.9958333333333332
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.99581589958159
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.6986115257785217
#
# Preselection
#
# (3844, 100)
# -
# 2877
# 0.7484463312958747
# -
# -
# 2735
# 0.9506430309350017
# -
# -
# 2690
# 0.9835470147193816
# -
# -
# 2669
# 0.9921941358762011
# -
# -
# 2648
# 0.9921331462780637
# -
# Object selection: rf
#
# Draw object selection results
#
# Classification Accuracy
# 0.9950906344410876
# Dfmf
#
# Parameters
#
# 18 10 8 8
#
#
# auc: 0.6900580291977048

# %%
cv_results_file = '../results/cv-generated-data-r-2-n-04-l-100-random.csv'
scores = []
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='random')
    selection.transform(ids=ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=text_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    score = selection.evaluate(evaluation_metric='auc')
    scores.append(score)
    
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

scores.sort()
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

results_file = '../scores/generated-data-r-2-n-04-l-100-random.csv'
save_scores(scores, results_file)
# Out:
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 18 16 2 2
#
#
# auc: 0.7282894286691755
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6805106076950738
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.7017825477021016
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6984704585604493
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6727598566308244
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6983515836772154
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6790791126567244
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.7005831922384369
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.69257425913104
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 6 6
#
#
# auc: 0.6909016190220658

# %%
cv_results_file = '../results/cv-generated-data-r-2-n-04-l-100-knn.csv'
scores = []
for _ in range(10):
    selection = BasicFactorization(show_selection_results=True, selection_algorithm='random')
    selection.transform(ids=ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=text_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    score = selection.evaluate(evaluation_metric='auc')
    scores.append(score)
    
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

scores.sort()
plt.title('AUC za izbrane slike')
plt.plot(scores)
plt.ylabel('AUC')
plt.show()

results_file = '../scores/generated-data-r-2-n-04-l-100-b.csv'
save_scores(scores, results_file)
# Out:
# Object selection: random
#
# Dfmf
#
# auc: 0.7076488095238096
# Object selection: random
#
# Dfmf
#
# auc: 0.7231792816094343
# Object selection: random
#
# Dfmf
#
# auc: 0.7299438758666226
# Object selection: random
#
# Dfmf
#
# auc: 0.6993223121596415
# Object selection: random
#
# Dfmf
#
# auc: 0.7247845703531919
# Object selection: random
#
# Dfmf
#
# auc: 0.7214218163060155
# Object selection: random
#
# Dfmf
#
# auc: 0.6954097284209014
# Object selection: random
#
# Dfmf
#
# auc: 0.7177981530708313
# Object selection: random
#
# Dfmf
#
# auc: 0.7174052565116633
# Object selection: random
#
# Dfmf
#
# auc: 0.7192779312807464
