# %%
import os
import sys
parent_dir = os.path.split(os.getcwd())[0]
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import random
import pickle

from utils import get_features
from object_selection import ObjectSelection
from load_data import load_data

# Parameters
data_directory = '../../data/generated-data-r-2-n-6-4/'
features_path = '../../data/features-generated-data-r-2-n-6-4'
booking_file = '../../data/booking.csv'
users_file = '../../data/user.csv'
rating_thresholds = [1, 7]

file_names = os.listdir(data_directory)
img_ids_vector = [int(name.split('-')[0]) for name in file_names]
ratings_vector = [int(name.split('-')[-2]) for name in file_names]
name_vector = [data_directory + name for name in file_names]

ratings_matrix, images_indexes_for_id, ids_indexes, users_matrix = load_data(data_directory, booking_file, users_file, rating_thresholds)

features = get_features(features_path, name_vector)
# Out:
# /Users/tinaavbelj/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/tinaavbelj/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
# Random selection
cv_results_file = '../results/cv-generated-data-r-2-n-3-3-random.csv'
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='random')
    selection.transform(ids=img_ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix, users=users_matrix, cv_results_file=cv_results_file)
    selection.evaluate(evaluation_metric='auc')
    selection.evaluate(evaluation_metric='rmse')
    print('\n\n-----\n\n')
# Out:
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.7060290535423078
#
# rmse: 1.0741788712303828
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.6964566552009406
#
# rmse: 1.0823435876924683
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.7226821505376344
#
# rmse: 1.0558310365921164
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.6910136752136753
#
# rmse: 1.1032234912407566
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.7045187714231735
#
# rmse: 1.057874370584642
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.695758441050744
#
# rmse: 1.0751800867020043
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.6967395248380128
#
# rmse: 1.0938288258563535
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.7164964023893565
#
# rmse: 1.0648782221064244
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.7064597797285737
#
# rmse: 1.0639408705864224
#
#
# -----
#
#
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 10 10 2 2
#
#
# auc: 0.7015818862202631
#
# rmse: 1.093660346300742
#
#
# -----

# %%
# K Nearest Neighbors
cv_results_file = '../results/cv-generated-data-r-2-n-6-4-knn.csv'
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='knn')
    selection.transform(ids=img_ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix, users=users_matrix, cv_results_file=cv_results_file)
    selection.evaluate(evaluation_metric='auc')
    selection.evaluate(evaluation_metric='rmse')
    print('\n\n-----\n\n')
# Out:
# Object selection: knn
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f87fe996cc89> in <module>
#       3 for _ in range(10):
#       4     selection = ObjectSelection(show_selection_results=True, selection_algorithm='knn')
# ----> 5     selection.transform(ids=img_ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix, users=users_matrix, cv_results_file=cv_results_file)
#       6     selection.evaluate(evaluation_metric='auc')
#       7     selection.evaluate(evaluation_metric='rmse')
#
# ~/Mag/tourism-recommender-system/object-selection/object_selection.py in transform(self, ids, features, ratings, users_ratings, users, cv_results_file)
#     470         self.save_ids_to_i()
#     471
# --> 472         selected_objects_i_for_ids = self.object_selection()
#     473         self.save_data_for_factorization(selected_objects_i_for_ids)
#     474         self.factorization(cv_results_file)
#
# ~/Mag/tourism-recommender-system/object-selection/object_selection.py in object_selection(self)
#     145                 continue
#     146
# --> 147             model.fit(train_X, train_y)
#     148             predicted_categories_probabilities = model.predict_proba(test_X)
#     149             ordered_classes = list(set(train_y.copy()))
#
# ~/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/sklearn/neighbors/_base.py in fit(self, X, y)
#    1155             self._y = self._y.ravel()
#    1156
# -> 1157         return self._fit(X)
#    1158
#    1159     def _more_tags(self):
#
# ~/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/sklearn/neighbors/_base.py in _fit(self, X)
#     456             self._tree = KDTree(X, self.leaf_size,
#     457                                 metric=self.effective_metric_,
# --> 458                                 **self.effective_metric_params_)
#     459         elif self._fit_method == 'brute':
#     460             self._tree = None
#
# KeyboardInterrupt:
