# %%
import os
import sys
parent_dir = os.path.split(os.getcwd())[0]
if parent_dir not in sys.path:
    sys.path.append(parent_dir)

import random
import pickle

from utils import get_features
from object_selection import ObjectSelection
from load_data import load_data

# Parameters
data_directory = '../../data/generated-data-r-2-n-8-2/'
features_path = '../../data/features-generated-data-r-2-n-8-2'
booking_file = '../../data/booking.csv'
users_file = '../../data/user.csv'
rating_thresholds = [1, 7]
true_objects_indexes = [0, 1, 2, 3, 4, 5, 6, 7]
false_objects_indexes = [8, 9]

file_names = os.listdir(data_directory)
img_ids_vector = [int(name.split('-')[0]) for name in file_names]
ratings_vector = [int(name.split('-')[-2]) for name in file_names]
name_vector = [data_directory + name for name in file_names]
images_indexes = [name.split('-')[3].split('.')[0] for name in file_names]
rating_thresholds = [1, 7]

ratings_matrix, images_indexes_for_id, ids_indexes, users_matrix = load_data(data_directory, booking_file,
                                                                             users_file, rating_thresholds)

features = get_features(features_path, name_vector)

cv_results_file = '../results/cv-generated-data-r-2-n-8-2-knn.csv'
for _ in range(5):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='knn')
    selection.transform(ids=img_ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=images_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    selection.evaluate(evaluation_metric='auc')
# Out:
# /Users/tinaavbelj/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# /Users/tinaavbelj/Mag/tourism-recommender-system/venv/lib/python3.7/site-packages/pandas/compat/__init__.py:85: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.712793984962406
#
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.6949635300500332
#
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7162427619060656
#
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7070645771000906
#
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.6977245492486329

# %%
cv_results_file = '../results/cv-generated-data-r-2-n-8-2-knn.csv'
for _ in range(5):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='knn')
    selection.transform(ids=img_ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                        users=users_matrix, cv_results_file=cv_results_file, images_indexes=images_indexes,
                        true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                        paths=name_vector)
    selection.evaluate(evaluation_metric='auc')
# Out:
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7314531814392887
#
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7160230211026775
#
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.6875226695683714
#
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7072206690446351
#
# Preselection
#
# (3000, 2048)
# -
# 2278
# 0.7593333333333333
# -
# -
# 2206
# 0.9683979381919885
# -
# -
# 2202
# 0.9981859410430839
# -
# -
# 2202
# 1.0
# -
# -
# 2202
# 1.0
# -
# Object selection: knn
#
# Draw object selection results
#
# Classification Accuracy
# 0.997275204359673
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.69574534403491

# %%
for _ in range(10):
    selection = ObjectSelection(show_selection_results=True, selection_algorithm='random')
    selection.transform(ids=img_ids_vector, features=features, ratings=ratings_vector, users_ratings=ratings_matrix,
                    users=users_matrix, cv_results_file=cv_results_file, images_indexes=images_indexes,
                    true_objects_indexes=true_objects_indexes, false_objects_indexes=false_objects_indexes,
                    paths=name_vector)
    selection.evaluate(evaluation_metric='auc')
# Out:
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7122200246800886
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.6866572135568716
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7123374732334047
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.6852177432837923
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7071371593891328
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.6840690149728278
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7034338665255675
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.7093759977650064
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.6911443921552787
# Object selection: random
#
# Dfmf
#
# Parameters
#
# 12 12 2 2
#
#
# auc: 0.6701216975942251
